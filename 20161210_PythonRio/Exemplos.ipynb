# %% [markdown]
# <h1 style="display: inline-block;"> Exemplos </h1> <h4 style="display: inline-block; float: right;"> 4- Exemplos.ipynb </h4>
#
# ### Mais interações!

# %%
from IPython.display import Image
Image("noworkflow.png")

# %%
from IPython.display import Image
Image("ipythonunittest.png")

# %% [markdown]
# https://github.com/JoaoFelipe/presentations/20161210_PythonRio
#
# <span style="font-size:1.5em;" id="slidepagination"> [<(3) IPython](IPython.ipynb) (4) [Extensões (5)>](Extensoes.ipynb) </span>
# &nbsp;

# %%
import pagination
